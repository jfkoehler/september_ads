# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./January 3-10, 2018 - Core Trends Survey - CSV.csv')


df = df.replace(' ', np.nan)

df.head()
# Out:
#    respid  sample  comp  int_date  lang  cregion  state  density usr  qs1  \
# 0       1       1     1    180103     1        1     42        5   U  NaN
# 1       2       1     1    180103     1        3     45        2   S  NaN
# 2       3       1     1    180103     1        1     34        5   S  NaN
# 3       4       1     1    180103     1        3     24        4   S  NaN
# 4       5       1     1    180103     1        1     33        2   R  NaN
#
#    ...  inc  party  partyln hh1  hh3 ql1 ql1a  qc1    weight  cellweight
# 0  ...    6      2      NaN   5    4   1  NaN  NaN  1.746359         NaN
# 1  ...    4      3        8   2    2   2    2  NaN  1.659764         NaN
# 2  ...    4      1      NaN   1  NaN   1  NaN  NaN  0.490804         NaN
# 3  ...    2      2      NaN   2    2   1  NaN  NaN  0.947965         NaN
# 4  ...    7      1      NaN   3    3   1  NaN  NaN  0.915959         NaN
#
# [5 rows x 70 columns]

# %%
df.shape
# Out:
# (2002, 70)

# %%
intfreq = list(df['intfreq'].astype(float).dropna().values)
respid = list(df['respid'].astype(int).dropna().values)
sex =  list(df['sex'].astype(int).dropna().values)
age = list(df['age'].astype(int).dropna().values)

# %%
intfreq_array = np.array(intfreq)

# %%
intfreq_array.shape
# Out:
# (1785,)

# %% [markdown]
# # Outline
# - Social media usage data
# - NumPy functions
# - Seeing available functions

# %%
social_list = [respid, sex, age, intfreq_array]

# %%
social = np.array(social_list)

# %%
type(social)
# Out:
# numpy.ndarray

# %%
np.mean(social[3])
# Out:
# 2.15406162464986

# %%
np.median(social[3])
# Out:
# 2.0

# %%
min(age)
# Out:
# 18

# %%
max(age)
# Out:
# 99

# %%
np.corrcoef(social[3], social[2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-0fa3551314e2> in <module>
# ----> 1 np.corrcoef(social[3], social[2])
#
# <__array_function__ internals> in corrcoef(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2524         warnings.warn('bias and ddof have no effect and are deprecated',
#    2525                       DeprecationWarning, stacklevel=3)
# -> 2526     c = cov(x, y, rowvar)
#    2527     try:
#    2528         d = diag(c)
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2388         if not rowvar and y.shape[0] != 1:
#    2389             y = y.T
# -> 2390         X = np.concatenate((X, y), axis=0)
#    2391
#    2392     if ddof is None:
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 1785 and the array at index 1 has size 2002

# %%
social.shape
# Out:
# (4,)

# %%
len(social[1])
# Out:
# 2002

# %%
len(social[2])
# Out:
# 2002

# %%
np.corrcoef(social[1], social[2])
# Out:
# array([[1.        , 0.09715812],
#        [0.09715812, 1.        ]])

# %%
df.head()
# Out:
#    respid  sample  comp  int_date  lang  cregion  state  density usr  qs1  \
# 0       1       1     1    180103     1        1     42        5   U  NaN
# 1       2       1     1    180103     1        3     45        2   S  NaN
# 2       3       1     1    180103     1        1     34        5   S  NaN
# 3       4       1     1    180103     1        3     24        4   S  NaN
# 4       5       1     1    180103     1        1     33        2   R  NaN
#
#    ...  inc  party  partyln hh1  hh3 ql1 ql1a  qc1    weight  cellweight
# 0  ...    6      2      NaN   5    4   1  NaN  NaN  1.746359         NaN
# 1  ...    4      3        8   2    2   2    2  NaN  1.659764         NaN
# 2  ...    4      1      NaN   1  NaN   1  NaN  NaN  0.490804         NaN
# 3  ...    2      2      NaN   2    2   1  NaN  NaN  0.947965         NaN
# 4  ...    7      1      NaN   3    3   1  NaN  NaN  0.915959         NaN
#
# [5 rows x 70 columns]

# %%
df.describe()
# Out:
#               respid       sample    comp       int_date         lang  \
# count    2002.000000  2002.000000  2002.0    2002.000000  2002.000000
# mean    76009.782717     1.750250     1.0  180105.636863     1.085415
# std     43691.053230     0.432977     0.0       2.275502     0.279567
# min         1.000000     1.000000     1.0  180103.000000     1.000000
# 25%    100004.000000     2.000000     1.0  180104.000000     1.000000
# 50%    100819.000000     2.000000     1.0  180105.000000     1.000000
# 75%    101577.500000     2.000000     1.0  180108.000000     1.000000
# max    102430.000000     2.000000     1.0  180110.000000     2.000000
#
#            cregion        state      density          sex      eminuse  ...  \
# count  2002.000000  2002.000000  2002.000000  2002.000000  2002.000000  ...
# mean      2.677822    28.155345     3.046454     1.460040     1.139361  ...
# std       1.014930    16.061673     1.416099     0.498525     0.375485  ...
# min       1.000000     1.000000     1.000000     1.000000     1.000000  ...
# 25%       2.000000    12.000000     2.000000     1.000000     1.000000  ...
# 50%       3.000000    28.000000     3.000000     1.000000     1.000000  ...
# 75%       3.000000    42.000000     4.000000     2.000000     1.000000  ...
# max       4.000000    56.000000     5.000000     2.000000     8.000000  ...
#
#            marital       educ2       emplnw         hisp       racem1  \
# count  2002.000000  2002.00000  2002.000000  2002.000000  2002.000000
# mean      2.980020     6.24975     3.457043     1.981019     2.101898
# std       2.260983    11.92625    10.404676     1.073342     2.226236
# min       1.000000     1.00000     1.000000     1.000000     1.000000
# 25%       1.000000     3.00000     1.000000     2.000000     1.000000
# 50%       2.000000     5.00000     2.000000     2.000000     1.000000
# 75%       5.000000     6.00000     3.000000     2.000000     2.000000
# max       9.000000    99.00000    99.000000     9.000000     9.000000
#
#            racecmb          inc        party          hh1       weight
# count  2002.000000  2002.000000  2002.000000  2002.000000  2002.000000
# mean      2.036464    21.068432     2.706294     3.012987     1.000000
# std       2.009017    35.128846     1.836563     1.939575     0.484119
# min       1.000000     1.000000     1.000000     1.000000     0.376175
# 25%       1.000000     3.000000     2.000000     2.000000     0.630608
# 50%       1.000000     6.000000     2.000000     2.000000     0.890626
# 75%       2.000000     9.000000     3.000000     4.000000     1.276018
# max       9.000000    99.000000     9.000000     9.000000     2.112972
#
# [8 rows x 30 columns]

# %%
df.describe(include = 'all')
# Out:
#                respid       sample    comp       int_date         lang  \
# count     2002.000000  2002.000000  2002.0    2002.000000  2002.000000
# unique            NaN          NaN     NaN            NaN          NaN
# top               NaN          NaN     NaN            NaN          NaN
# freq              NaN          NaN     NaN            NaN          NaN
# mean     76009.782717     1.750250     1.0  180105.636863     1.085415
# std      43691.053230     0.432977     0.0       2.275502     0.279567
# min          1.000000     1.000000     1.0  180103.000000     1.000000
# 25%     100004.000000     2.000000     1.0  180104.000000     1.000000
# 50%     100819.000000     2.000000     1.0  180105.000000     1.000000
# 75%     101577.500000     2.000000     1.0  180108.000000     1.000000
# max     102430.000000     2.000000     1.0  180110.000000     2.000000
#
#             cregion        state      density   usr   qs1  ...          inc  \
# count   2002.000000  2002.000000  2002.000000  1854  1502  ...  2002.000000
# unique          NaN          NaN          NaN     3     1  ...          NaN
# top             NaN          NaN          NaN     S     2  ...          NaN
# freq            NaN          NaN          NaN   877  1502  ...          NaN
# mean       2.677822    28.155345     3.046454   NaN   NaN  ...    21.068432
# std        1.014930    16.061673     1.416099   NaN   NaN  ...    35.128846
# min        1.000000     1.000000     1.000000   NaN   NaN  ...     1.000000
# 25%        2.000000    12.000000     2.000000   NaN   NaN  ...     3.000000
# 50%        3.000000    28.000000     3.000000   NaN   NaN  ...     6.000000
# 75%        3.000000    42.000000     4.000000   NaN   NaN  ...     9.000000
# max        4.000000    56.000000     5.000000   NaN   NaN  ...    99.000000
#
#               party  partyln          hh1   hh3  ql1 ql1a   qc1       weight  \
# count   2002.000000      954  2002.000000  1596  500   50  1502  2002.000000
# unique          NaN        4          NaN     9    3    3     3          NaN
# top             NaN        2          NaN     2    1    9     2          NaN
# freq            NaN      326          NaN   945  420   19   921          NaN
# mean       2.706294      NaN     3.012987   NaN  NaN  NaN   NaN     1.000000
# std        1.836563      NaN     1.939575   NaN  NaN  NaN   NaN     0.484119
# min        1.000000      NaN     1.000000   NaN  NaN  NaN   NaN     0.376175
# 25%        2.000000      NaN     2.000000   NaN  NaN  NaN   NaN     0.630608
# 50%        2.000000      NaN     2.000000   NaN  NaN  NaN   NaN     0.890626
# 75%        3.000000      NaN     4.000000   NaN  NaN  NaN   NaN     1.276018
# max        9.000000      NaN     9.000000   NaN  NaN  NaN   NaN     2.112972
#
#         cellweight
# count         1502
# unique         827
# top       .4333029
# freq            76
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [11 rows x 70 columns]

# %%
# df.head()
# df.info()
# df.describe()
df['usr'].value_counts().plot(kind = 'bar')

# %%
df[['sample', 'comp']]
# Out:
#       sample  comp
# 0          1     1
# 1          1     1
# 2          1     1
# 3          1     1
# 4          1     1
# ...      ...   ...
# 1997       2     1
# 1998       2     1
# 1999       2     1
# 2000       2     1
# 2001       2     1
#
# [2002 rows x 2 columns]

# %%
df.loc[:5, ['sample', 'comp']]
# Out:
#    sample  comp
# 0       1     1
# 1       1     1
# 2       1     1
# 3       1     1
# 4       1     1
# 5       1     1

# %%
df.iloc[:5, [1,2]]
# Out:
#    sample  comp
# 0       1     1
# 1       1     1
# 2       1     1
# 3       1     1
# 4       1     1

# %%
df.head()
# Out:
#    respid  sample  comp  int_date  lang  cregion  state  density usr  qs1  \
# 0       1       1     1    180103     1        1     42        5   U  NaN
# 1       2       1     1    180103     1        3     45        2   S  NaN
# 2       3       1     1    180103     1        1     34        5   S  NaN
# 3       4       1     1    180103     1        3     24        4   S  NaN
# 4       5       1     1    180103     1        1     33        2   R  NaN
#
#    ...  inc  party  partyln hh1  hh3 ql1 ql1a  qc1    weight  cellweight
# 0  ...    6      2      NaN   5    4   1  NaN  NaN  1.746359         NaN
# 1  ...    4      3        8   2    2   2    2  NaN  1.659764         NaN
# 2  ...    4      1      NaN   1  NaN   1  NaN  NaN  0.490804         NaN
# 3  ...    2      2      NaN   2    2   1  NaN  NaN  0.947965         NaN
# 4  ...    7      1      NaN   3    3   1  NaN  NaN  0.915959         NaN
#
# [5 rows x 70 columns]
