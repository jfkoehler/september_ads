# %% [markdown]
# ### ADS: Week 4
#
# ![](../ads_ohours_cover.png)

# %%
import pandas as pd

# %%
df = pd.read_csv('data/patients.csv')

# %%
df.head(10)
# Out:
#    gender   age  diabetes  hypertension  stroke  heart disease  \
# 0  Female  80.0         0             0       0              1
# 1  Female  54.0         0             0       0              0
# 2    Male  28.0         0             0       0              0
# 3  Female  36.0         0             0       0              0
# 4    Male  76.0         0             1       0              1
# 5  Female  20.0         0             0       0              0
# 6  Female  44.0         1             0       0              0
# 7  Female  79.0         0             0       0              0
# 8    Male  42.0         0             0       0              0
# 9  Female  32.0         0             0       0              0
#
#   smoking history    BMI
# 0           never  25.19
# 1             NaN    NaN
# 2           never    NaN
# 3         current  23.45
# 4         current  20.14
# 5           never    NaN
# 6           never  19.31
# 7             NaN  23.86
# 8           never  33.64
# ...

# %%
# !unzip Week\ 4\ -\ Jupyter\ Notebooks.zip
# Out:
# Archive:  Week 4 - Jupyter Notebooks.zip
#   inflating: 4_1_Packages.ipynb
#   inflating: 4_2_Getting Started with NumPy Arrays.ipynb
#   inflating: 4_3_Getting Started with 2D NumPy Arrays.ipynb
#   inflating: 4_4_Looping Over NumPy Arrays.ipynb
#   inflating: 4_5_Getting Started with Pandas Creating DataFrames.ipynb
#   inflating: 4_6_Getting Started with Pandas Slicing and Filtering DataFrames.ipynb
#   inflating: 4_7_NumPy and Pandas Statistical Tools.ipynb
#   inflating: January 3-10, 2018 - Core Trends Survey - CSV.csv

# %%
df.describe()
# Out:
#                  age       diabetes  hypertension         stroke  \
# count  100000.000000  100000.000000  100000.00000  100000.000000
# mean       41.885856       0.085000       0.07485       0.014260
# std        22.516840       0.278883       0.26315       0.118561
# min         0.080000       0.000000       0.00000       0.000000
# 25%        24.000000       0.000000       0.00000       0.000000
# 50%        43.000000       0.000000       0.00000       0.000000
# 75%        60.000000       0.000000       0.00000       0.000000
# max        80.000000       1.000000       1.00000       1.000000
#
#        heart disease           BMI
# count  100000.000000  74556.000000
# mean        0.039420     27.321029
# std         0.194593      7.686296
# min         0.000000     10.010000
# 25%         0.000000     22.030000
# 50%         0.000000     26.500000
# 75%         0.000000     31.530000
# max         1.000000     95.690000

# %%
df['smoking history'].value_counts()
# Out:
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: smoking history, dtype: int64

# %%
df['smoking history'].value_counts().plot(kind = 'barh')

# %%
groups_gender = df.groupby('gender')

# %%
for group in groups_gender:
    print(group)
# Out:
# ('Female',        gender   age  diabetes  hypertension  stroke  heart disease  \
# 0      Female  80.0         0             0       0              1
# 1      Female  54.0         0             0       0              0
# 3      Female  36.0         0             0       0              0
# 5      Female  20.0         0             0       0              0
# 6      Female  44.0         1             0       0              0
# ...       ...   ...       ...           ...     ...            ...
# 99994  Female  36.0         0             0       0              0
# 99995  Female  80.0         0             0       0              0
# 99996  Female   2.0         0             0       0              0
# 99998  Female  24.0         0             0       0              0
# 99999  Female  57.0         0             0       0              0
#
#       smoking history    BMI
# 0               never  25.19
# 1                 NaN    NaN
# 3             current  23.45
# 5               never    NaN
# ...

# %%
df.groupby('gender')['age'].mean().plot(kind = 'barh')

# %%
df.head(2)
# Out:
#    gender   age  diabetes  hypertension  stroke  heart disease  \
# 0  Female  80.0         0             0       0              1
# 1  Female  54.0         0             0       0              0
#
#   smoking history    BMI
# 0           never  25.19
# 1             NaN    NaN

# %%
df.groupby('smoking history')['BMI'].mean().plot(kind = 'barh')

# %%
df.groupby(['gender', 'smoking history'])['BMI'].mean()
# Out:
# gender  smoking history
# Female  current            28.631990
#         ever               29.003811
#         former             29.926124
#         never              28.250244
#         not current        28.652281
# Male    current            28.880340
#         ever               29.049180
#         former             30.240531
#         never              28.292043
#         not current        28.434475
# Other   ever                     NaN
#         never              36.760000
#         not current        25.480000
# Name: BMI, dtype: float64

# %%
# df.info()
# df.head()
# df.tail()
# df.describe()
# df.loc[:, ['gender']]
# df.iloc[:4, [4, 5, 10]]
# df.groupby('gender')['BMI'].mean()

# %%
df.loc[df['age'] > 60]['BMI'].mean()
# Out:
# 28.926371986894544

# %%
df.loc[df['age'] <= 60]['BMI'].mean()
# Out:
# 26.84353821523041

# %%
df.loc[(df['age'] <= 60) & (df['heart disease'] == 1)]['BMI'].mean()
# Out:
# 31.736004872107195

# %%
df.nlargest(10, 'BMI')
# Out:
#        gender   age  diabetes  hypertension  stroke  heart disease  \
# 87843    Male   7.0         0             0       0              0
# 76093    Male  16.0         0             0       0              0
# 69549    Male  38.0         0             0       0              0
# 96066    Male  80.0         0             0       0              0
# 4551   Female  45.0         1             0       0              0
# 90043  Female  34.0         0             0       0              0
# 22454    Male  19.0         0             0       0              0
# 24186    Male  49.0         1             0       0              0
# 71485  Female  48.0         1             0       0              0
# 20591  Female  39.0         0             0       0              0
#
#       smoking history    BMI
# 87843             NaN  95.69
# 76093             NaN  95.22
# 69549           never  91.82
# 96066           never  88.76
# 4551            never  88.72
# 90043             NaN  87.70
# ...

# %%
df.nsmallest(10, 'age')
# Out:
#        gender   age  diabetes  hypertension  stroke  heart disease  \
# 155    Female  0.08         0             0       0              0
# 2049   Female  0.08         0             0       0              0
# 3742     Male  0.08         0             0       0              0
# 9683   Female  0.08         0             0       0              0
# 13162    Male  0.08         0             0       0              0
# 16028    Male  0.08         0             0       0              0
# 29551    Male  0.08         0             0       0              0
# 30060    Male  0.08         0             0       0              0
# 32402    Male  0.08         0             0       0              0
# 33684    Male  0.08         0             0       0              0
#
#       smoking history    BMI
# 155               NaN  14.43
# 2049              NaN  13.35
# 3742              NaN  12.80
# 9683              NaN  11.88
# 13162             NaN    NaN
# 16028             NaN  14.40
# ...

# %%
df['gender'].nunique()
# Out:
# 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   gender           100000 non-null  object
#  1   age              100000 non-null  float64
#  2   diabetes         100000 non-null  int64
#  3   hypertension     100000 non-null  int64
#  4   stroke           100000 non-null  int64
#  5   heart disease    100000 non-null  int64
#  6   smoking history  64184 non-null   object
#  7   BMI              74556 non-null   float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 6.1+ MB

# %%
df['smoking history'] = df['smoking history'].fillna('unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   gender           100000 non-null  object
#  1   age              100000 non-null  float64
#  2   diabetes         100000 non-null  int64
#  3   hypertension     100000 non-null  int64
#  4   stroke           100000 non-null  int64
#  5   heart disease    100000 non-null  int64
#  6   smoking history  100000 non-null  object
#  7   BMI              74556 non-null   float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 6.1+ MB

# %%
df['BMI'].fillna(df['BMI'].mean(), inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   gender           100000 non-null  object
#  1   age              100000 non-null  float64
#  2   diabetes         100000 non-null  int64
#  3   hypertension     100000 non-null  int64
#  4   stroke           100000 non-null  int64
#  5   heart disease    100000 non-null  int64
#  6   smoking history  100000 non-null  object
#  7   BMI              100000 non-null  float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 6.1+ MB

# %%
df['age_bins'] = pd.qcut(df['age'], 4)

# %%
df.groupby('age_bins').mean()
# Out:
#                      age  diabetes  hypertension    stroke  heart disease  \
# age_bins
# (0.079, 24.0]  12.605857  0.005988      0.001507  0.000232       0.000348
# (24.0, 43.0]   34.161379  0.034513      0.029816  0.002070       0.003861
# (43.0, 60.0]   51.911324  0.108785      0.100741  0.011277       0.035683
# (60.0, 80.0]   71.409106  0.199687      0.175271  0.045785       0.124027
#
#                      BMI
# age_bins
# (0.079, 24.0]  22.828423
# (24.0, 43.0]   28.686488
# (43.0, 60.0]   29.471919
# (60.0, 80.0]   28.482104

# %%
df.groupby('age_bins').count()
# Out:
#                gender    age  diabetes  hypertension  stroke  heart disease  \
# age_bins
# (0.079, 24.0]   25885  25885     25885         25885   25885          25885
# (24.0, 43.0]    25121  25121     25121         25121   25121          25121
# (43.0, 60.0]    25362  25362     25362         25362   25362          25362
# (60.0, 80.0]    23632  23632     23632         23632   23632          23632
#
#                smoking history    BMI
# age_bins
# (0.079, 24.0]            25885  25885
# (24.0, 43.0]             25121  25121
# (43.0, 60.0]             25362  25362
# (60.0, 80.0]             23632  23632

# %%
pd.read_csv('data/dataset_37_diabetes.csv')
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]
